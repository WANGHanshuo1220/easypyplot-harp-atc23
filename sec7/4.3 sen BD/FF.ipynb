# %%
''' Required packages. Use python3 -m pip install xxx for all the packages. '''
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.font_manager as fm
from matplotlib import pyplot as plt
import easypyplot

# %%
''' Plot parameters. Change only if you want to resize the graph, etc. '''
fig_bar_width = 0.75
fig_dims = (10, 2)
fig_label_fontsize = 12
xy_label_size = 12
ft = fm.FontProperties('Times New Roman')
ft.set_size(fig_label_fontsize)

fig_name = 'graph_sensitivity'

# %%
fig_scheme_list = ['Pacman Read Access', 'Pacman Write Access',
                   'Harp Read Access', 'Harp Write Access']
fig_scheme_dict = {item: item for item in fig_scheme_list}

fig_title = 'Sensitivity'
fig_name = '4.3 Sensitivity breakdown'
fig_path = '../../4.3/'
fig_ylim = (0, 2)
fig_yticks = list(np.arange(fig_ylim[0], fig_ylim[1]+0.01, 0.4))
fig_bar_colors = [easypyplot.color.COLOR_SET[i] for i in [0, 1]]
design_colors = fig_bar_colors
baseline_colors = easypyplot.color.color_scale(design_colors[0], 2, 0.5, 0.75)[::-1]
igc_colors = easypyplot.color.color_scale(design_colors[1], 2, 0.5, 0.75)[::-1]
design_len = 2
assert len(fig_bar_colors) == design_len

# %%
''' Load wirte ratio data '''
csv_path = 'write_ratio.csv'
workload_list_WR = ['0', '20', '40', '60', '80', '100']
workload_dict = {item: item for item in workload_list_WR}

# pprint(fig_yticks)
csv_hd = pd.read_csv(csv_path, sep=',')
fig_xlabels_WR = []
baseline_xticks_WR = []
fig_data_WR = []
xtick_WR = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list_WR):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in fig_scheme_dict):
                row_value.append(row[col])
        fig_data_WR.append(row_value)
        fig_xlabels_WR.append(workload_fullname)
        xtick_WR += 2
        baseline_xticks_WR.append(xtick_WR)
assert len(fig_data_WR) == len(fig_xlabels_WR) == len(baseline_xticks_WR)
igc_xticks_WR = [item + fig_bar_width for item in baseline_xticks_WR]

pprint(fig_data_WR)

''' Layout hit rate '''
layout_scheme_list = ['Pacman GC', 'Harp GC']
layout_scheme_dict = {item: item for item in layout_scheme_list}
csv_hd = pd.read_csv(csv_path, sep=',')
layout_xlabels_WR = []
layout_xticks_WR = []
layout_data_WR = []
xtick_WR = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list_WR):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in layout_scheme_dict):
                row_value.append(row[col])
        layout_data_WR.append(row_value)
        layout_xlabels_WR.append(workload_fullname)
        xtick_WR += 1
        layout_xticks_WR.append(xtick_WR)
assert len(layout_data_WR) == len(layout_xlabels_WR) == len(layout_xticks_WR)

pprint(layout_data_WR)
# Out:
# [[0.0, 0.0, 0.0, 0.0],
#  [0.11395999999999999, 0.0, 0.0, 0.0],
#  [0.4388, 0.02427, 0.1466, 0.01952],
#  [0.8289799999999999, 0.11002999999999999, 0.33975, 0.0839],
#  [1.1919600000000001, 0.17347, 0.54847, 0.15122],
#  [1.52749, 0.20485, 0.80824, 0.1989]]
# [[0.0, 0.0],
#  [1.746, 0.16],
#  [6.776, 2.092],
#  [12.58, 5.446000000000001],
#  [18.339000000000002, 8.631],
#  [23.553, 12.333]]

# %%
''' Load util data '''
csv_path = 'util.csv'
workload_list_U = ['50', '60', '70', '80']
workload_dict = {item: item for item in workload_list_U}

# pprint(fig_yticks)
csv_hd = pd.read_csv(csv_path, sep=',')
fig_xlabels_U = []
baseline_xticks_U = []
fig_data_U = []
xtick_U = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list_U):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in fig_scheme_dict):
                row_value.append(row[col])
        fig_data_U.append(row_value)
        fig_xlabels_U.append(workload_fullname)
        xtick_U += 2
        baseline_xticks_U.append(xtick_U)
assert len(fig_data_U) == len(fig_xlabels_U) == len(baseline_xticks_U)
igc_xticks_U = [item + fig_bar_width for item in baseline_xticks_U]

pprint(fig_data_U)

''' Layout hit rate '''
layout_scheme_list = ['Pacman GC', 'Harp GC']
layout_scheme_dict = {item: item for item in layout_scheme_list}
csv_hd = pd.read_csv(csv_path, sep=',')
layout_xlabels_U = []
layout_xticks_U = []
layout_data_U = []
xtick_U = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list_U):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in layout_scheme_dict):
                row_value.append(row[col])
        layout_data_U.append(row_value)
        layout_xlabels_U.append(workload_fullname)
        xtick_U += 1
        layout_xticks_U.append(xtick_U)
assert len(layout_data_U) == len(layout_xlabels_U) == len(layout_xticks_U)

pprint(layout_data_U)
# Out:
# [[0.6127199999999999, 0.04803, 0.25111, 0.03857],
#  [0.7853399999999999, 0.15214, 0.27499, 0.13801],
#  [0.96824, 0.28724, 0.54513, 0.24866],
#  [1.23377, 0.52691, 0.8915799999999999, 0.56877]]
# [[9.615, 3.6210000000000004],
#  [12.229000000000001, 6.138],
#  [14.636, 8.585],
#  [18.994, 13.302]]

# %%
''' Load KV size data '''
csv_path = 'kv_size.csv'
workload_list_KVS = ['32', '64', '128', '256', '512']
workload_dict = {item: item for item in workload_list_KVS}

# pprint(fig_yticks)
csv_hd = pd.read_csv(csv_path, sep=',')
fig_xlabels_KVS = []
baseline_xticks_KVS = []
fig_data_KVS = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list_KVS):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in fig_scheme_dict):
                row_value.append(row[col])
        fig_data_KVS.append(row_value)
        fig_xlabels_KVS.append(workload_fullname)
        xtick += 2
        baseline_xticks_KVS.append(xtick)
assert len(fig_data_KVS) == len(fig_xlabels_KVS) == len(baseline_xticks_KVS)
igc_xticks_KVS = [item + fig_bar_width for item in baseline_xticks_KVS]

pprint(fig_data_KVS)

''' Layout hit rate '''
layout_scheme_list = ['Pacman GC', 'Harp GC']
layout_scheme_dict = {item: item for item in layout_scheme_list}
csv_hd = pd.read_csv(csv_path, sep=',')
layout_xlabels_KVS = []
layout_xticks_KVS = []
layout_data_KVS = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list_KVS):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in layout_scheme_dict):
                row_value.append(row[col])
        layout_data_KVS.append(row_value)
        layout_xlabels_KVS.append(workload_fullname)
        xtick += 1
        layout_xticks_KVS.append(xtick)
assert len(layout_data_KVS) == len(layout_xlabels_KVS) == len(layout_xticks_KVS)

pprint(layout_data_KVS)
# Out:
# [[0.6381100000000001, 0.0635, 0.23228000000000001, 0.04336],
#  [0.61244, 0.04836, 0.22938000000000003, 0.04156],
#  [0.60937, 0.05018, 0.19927, 0.034839999999999996],
#  [0.61429, 0.059579999999999994, 0.21955999999999998, 0.03594],
#  [0.60863, 0.05417, 0.37758, 0.03653]]
# [[7.249, 2.779],
#  [11.732000000000001, 4.327],
#  [21.069000000000003, 6.8420000000000005],
#  [39.698, 14.24],
#  [78.436, 47.63399999999999]]

# %%
''' Load key space data '''
csv_path = 'key_space.csv'
workload_list_KEYS = ['100', '200', '400', '600']
workload_dict = {item: item for item in workload_list_KEYS}

# pprint(fig_yticks)
csv_hd = pd.read_csv(csv_path, sep=',')
fig_xlabels_KEYS = []
baseline_xticks_KEYS = []
fig_data_KEYS = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list_KEYS):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in fig_scheme_dict):
                row_value.append(row[col])
        fig_data_KEYS.append(row_value)
        fig_xlabels_KEYS.append(workload_fullname)
        xtick += 2
        baseline_xticks_KEYS.append(xtick)
assert len(fig_data_KEYS) == len(fig_xlabels_KEYS) == len(baseline_xticks_KEYS)
igc_xticks_KEYS = [item + fig_bar_width for item in baseline_xticks_KEYS]

pprint(fig_data_KEYS)

''' Layout hit rate '''
layout_scheme_list = ['Pacman GC', 'Harp GC']
layout_scheme_dict = {item: item for item in layout_scheme_list}
csv_hd = pd.read_csv(csv_path, sep=',')
layout_xlabels_KEYS = []
layout_xticks_KEYS = []
layout_data_KEYS = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list_KEYS):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in layout_scheme_dict):
                row_value.append(row[col])
        layout_data_KEYS.append(row_value)
        layout_xlabels_KEYS.append(workload_fullname)
        xtick += 1
        layout_xticks_KEYS.append(xtick)
assert len(layout_data_KEYS) == len(layout_xlabels_KEYS) == len(layout_xticks_KEYS)

pprint(layout_data_KEYS)
# Out:
# [[0.8342200000000001, 0.1326, 0.39237, 0.10916],
#  [0.9083399999999999, 0.11853, 0.39353, 0.10445],
#  [1.0403200000000001, 0.7674, 0.3714, 0.06375],
#  [1.21175, 0.6029, 0.32259, 0.047689999999999996]]
# [[12.73, 5.987], [13.860999999999999, 6.004], [15.875, 5.666], [18.491, 4.922]]

# %%
p, fig = easypyplot.pdf.plot_setup(fig_path + fig_name, fig_dims)

''' plot write ratio '''
fig_ax = fig.add_subplot(1 ,4 ,1)
fig_ax2 = fig_ax.twinx()
easypyplot.format.turn_off_box(fig_ax, twinx_axes=fig_ax2)
fig_data_nparr = np.array(fig_data_WR)
baseline_acc_data = fig_data_nparr[:, :2]
igc_acc_data = fig_data_nparr[:, 2:4]
fig_h = []
fig_h += easypyplot.barchart.draw(
    fig_ax, baseline_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels_WR,
    xticks=baseline_xticks_WR,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=baseline_colors)
fig_h += easypyplot.barchart.draw(
    fig_ax, igc_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels_WR,
    xticks=igc_xticks_WR,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=igc_colors)
fig_h2 = []
# easypyplot.format.turn_off_box(ax2)
layout_data_nparr = np.array(layout_data_WR)
layout_xticks = [baseline_xticks_WR, igc_xticks_WR]
for group_id in range(design_len):
    print(layout_data_nparr[:, 0])
    fig_h2 += fig_ax2.plot(layout_xticks[group_id], layout_data_nparr[:, group_id],
                marker='*',
                linewidth = '1.0',
                color = '#000000',
                # color = baseline_colors[0],
                markersize = '7.0',
                # prop = ft
                )
''' x axis '''
fig_ax.set_xlim([fig_ax.get_xticks()[0] - 1, fig_ax.get_xticks()[-1] + 1])
avg_xticks = [(baseline_xticks_WR[i] + igc_xticks_WR[i])/2 for i in range(len(baseline_xticks_WR))]
fig_ax.set_xticks(avg_xticks)
fig_ax.set_xlim([0, len(workload_list_WR) * design_len + 1])
fig_ax.set_xticklabels(fig_xlabels_WR, fontsize=fig_label_fontsize, fontproperties=ft)
fig_ax.xaxis.set_ticks_position('none') # Comment this and the next line for visible ticks
# fig_ax.tick_params(direction='in') # [in, out, inout]
fig_ax.set_xlabel('Write Ratio (%)', fontproperties=ft)
''' y axis '''
fig_ax.yaxis.grid(True)
fig_ax.set_ylim(fig_ylim)
fig_ax.set_yticks(fig_yticks)
fig_ax.set_ylabel('# of Access (billion)', multialignment='center', fontproperties=ft)
layout_ylim = [0., 25.]
fig_ax2.set_ylim(layout_ylim)
fig_ax2.set_yticks(list(np.arange(layout_ylim[0], layout_ylim[1]+0.01, 5)))
# fig_ax2.set_ylabel('GC Latency', multialignment='center', fontproperties=ft)
fig_ax.tick_params(labelsize=xy_label_size)
fig_ax2.tick_params(labelsize=xy_label_size)
easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)


''' plot util '''
fig_ax = fig.add_subplot(1 ,4 ,2)
fig_ax2 = fig_ax.twinx()
easypyplot.format.turn_off_box(fig_ax, twinx_axes=fig_ax2)
fig_data_nparr = np.array(fig_data_U)
baseline_acc_data = fig_data_nparr[:, :2]
igc_acc_data = fig_data_nparr[:, 2:4]
# fig_h = []
fig_h += easypyplot.barchart.draw(
    fig_ax, baseline_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels_U,
    xticks=baseline_xticks_U,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=baseline_colors)
fig_h += easypyplot.barchart.draw(
    fig_ax, igc_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels_U,
    xticks=igc_xticks_U,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=igc_colors)
# fig_h2 = []
# easypyplot.format.turn_off_box(ax2)
layout_data_nparr = np.array(layout_data_U)
layout_xticks = [baseline_xticks_U, igc_xticks_U]
for group_id in range(design_len):
    print(layout_data_nparr[:, 0])
    fig_h2 += fig_ax2.plot(layout_xticks[group_id], layout_data_nparr[:, group_id],
                marker='*',
                linewidth = '1.0',
                color = '#000000',
                # color = baseline_colors[0],
                markersize = '7.0',
                # prop = ft
                )
''' x axis '''
fig_ax.set_xlim([fig_ax.get_xticks()[0] - 1, fig_ax.get_xticks()[-1] + 1])
avg_xticks = [(baseline_xticks_U[i] + igc_xticks_U[i])/2 for i in range(len(baseline_xticks_U))]
fig_ax.set_xticks(avg_xticks)
fig_ax.set_xlim([0, len(workload_list_U) * design_len + 1])
fig_ax.set_xticklabels(fig_xlabels_U, fontsize=fig_label_fontsize, fontproperties=ft)
fig_ax.xaxis.set_ticks_position('none') # Comment this and the next line for visible ticks
# fig_ax.tick_params(direction='in') # [in, out, inout]
fig_ax.set_xlabel('Capacity Utilization (%)', fontproperties=ft)
''' y axis '''
fig_ax.yaxis.grid(True)
fig_ax.set_ylim(fig_ylim)
fig_ax.set_yticks(fig_yticks)
# fig_ax.set_ylabel('Access Breakdown', multialignment='center', fontproperties=ft)
layout_ylim = [0., 20.]
fig_ax2.set_ylim(layout_ylim)
fig_ax2.set_yticks(list(np.arange(layout_ylim[0], layout_ylim[1]+0.01, 4)))
# fig_ax2.set_ylabel('GC Latency', multialignment='center', fontproperties=ft)
fig_ax.tick_params(labelsize=xy_label_size)
fig_ax2.tick_params(labelsize=xy_label_size)
easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)

''' plot kv size '''
fig_ax = fig.add_subplot(1 ,4 ,3)
fig_ax2 = fig_ax.twinx()
easypyplot.format.turn_off_box(fig_ax, twinx_axes=fig_ax2)
fig_data_nparr = np.array(fig_data_KVS)
baseline_acc_data = fig_data_nparr[:, :2]
igc_acc_data = fig_data_nparr[:, 2:4]
# fig_h = []
fig_h += easypyplot.barchart.draw(
    fig_ax, baseline_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels_KVS,
    xticks=baseline_xticks_KVS,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=baseline_colors)
fig_h += easypyplot.barchart.draw(
    fig_ax, igc_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels_KVS,
    xticks=igc_xticks_KVS,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=igc_colors)
# fig_h2 = []
# easypyplot.format.turn_off_box(ax2)
layout_data_nparr = np.array(layout_data_KVS)
layout_xticks = [baseline_xticks_KVS, igc_xticks_KVS]
for group_id in range(design_len):
    print(layout_data_nparr[:, 0])
    fig_h2 += fig_ax2.plot(layout_xticks[group_id], layout_data_nparr[:, group_id],
                marker='*',
                linewidth = '1.0',
                color = '#000000',
                # color = baseline_colors[0],
                markersize = '7.0',
                # prop = ft
                )
''' x axis '''
fig_ax.set_xlim([fig_ax.get_xticks()[0] - 1, fig_ax.get_xticks()[-1] + 1])
avg_xticks = [(baseline_xticks_KVS[i] + igc_xticks_KVS[i])/2 for i in range(len(baseline_xticks_KVS))]
fig_ax.set_xticks(avg_xticks)
fig_ax.set_xlim([0, len(workload_list_KVS) * design_len + 1])
fig_ax.set_xticklabels(fig_xlabels_KVS, fontsize=fig_label_fontsize, fontproperties=ft)
fig_ax.xaxis.set_ticks_position('none') # Comment this and the next line for visible ticks
# fig_ax.tick_params(direction='in') # [in, out, inout]
fig_ax.set_xlabel('Value Size (Bytes)', fontproperties=ft)
''' y axis '''
fig_ax.yaxis.grid(True)
fig_ylim_ = (0, 0.9)
fig_yticks_ = list(np.arange(fig_ylim_[0], fig_ylim_[1]+0.01, 0.2))
fig_ax.set_ylim(fig_ylim_)
fig_ax.set_yticks(fig_yticks_)
# fig_ax.set_ylabel('Access Breakdown', multialignment='center', fontproperties=ft)
layout_ylim = [0., 85.]
fig_ax2.set_ylim(layout_ylim)
fig_ax2.set_yticks(list(np.arange(layout_ylim[0], layout_ylim[1]+0.01, 20)))
# fig_ax2.set_ylabel('GC Latency', multialignment='center', fontproperties=ft)
fig_ax.tick_params(labelsize=xy_label_size)
fig_ax2.tick_params(labelsize=xy_label_size)
easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)

''' plot key space '''
fig_ax = fig.add_subplot(1 ,4 ,4)
fig_ax2 = fig_ax.twinx()
easypyplot.format.turn_off_box(fig_ax, twinx_axes=fig_ax2)
fig_data_nparr = np.array(fig_data_KEYS)
baseline_acc_data = fig_data_nparr[:, :2]
igc_acc_data = fig_data_nparr[:, 2:4]
# fig_h = []
fig_h += easypyplot.barchart.draw(
    fig_ax, baseline_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels_KEYS,
    xticks=baseline_xticks_KEYS,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=baseline_colors)
fig_h += easypyplot.barchart.draw(
    fig_ax, igc_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels_KEYS,
    xticks=igc_xticks_KEYS,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft, 
    colors=igc_colors)
# fig_h2 = []
# easypyplot.format.turn_off_box(fig)
layout_data_nparr = np.array(layout_data_KEYS)
layout_xticks = [baseline_xticks_KEYS, igc_xticks_KEYS]
for group_id in range(design_len):
    print(layout_data_nparr[:, 0])
    fig_h2 += fig_ax2.plot(layout_xticks[group_id], layout_data_nparr[:, group_id],
                marker='*',
                linewidth = '1.0',
                color = '#000000',
                # color = baseline_colors[0],
                markersize = '7.0',
                # prop = ft
                )
''' x axis '''
fig_ax.set_xlim([fig_ax.get_xticks()[0] - 1, fig_ax.get_xticks()[-1] + 1])
avg_xticks = [(baseline_xticks_KEYS[i] + igc_xticks_KEYS[i])/2 for i in range(len(baseline_xticks_KEYS))]
fig_ax.set_xticks(avg_xticks)
fig_ax.set_xlim([0, len(workload_list_KEYS) * design_len + 1])
fig_ax.set_xticklabels(fig_xlabels_KEYS, fontsize=fig_label_fontsize, fontproperties=ft)
fig_ax.xaxis.set_ticks_position('none') # Comment this and the next line for visible ticks
# fig_ax.tick_params(direction='in') # [in, out, inout]
fig_ax.set_xlabel('Key Space Size (M)', fontproperties=ft)
''' y axis '''
fig_ax.yaxis.grid(True)
fig_ylim_ = (0, 2.0)
fig_yticks_ = list(np.arange(fig_ylim_[0], fig_ylim_[1]+0.01, 0.4))
fig_ax.set_ylim(fig_ylim_)
fig_ax.set_yticks(fig_yticks_)
# fig_ax.set_ylabel('Access Breakdown', multialignment='center', fontproperties=ft)
layout_ylim = [0., 20.]
fig_ax2.set_ylim(layout_ylim)
fig_ax2.set_yticks(list(np.arange(layout_ylim[0], layout_ylim[1]+0.01, 4)))
fig_ax2.set_ylabel('# of GC (thousand)', multialignment='center', fontproperties=ft)
fig_ax.tick_params(labelsize=xy_label_size)
fig_ax2.tick_params(labelsize=xy_label_size)
easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)

''' legend '''
legend = [fig_scheme_dict[item] for item in fig_scheme_dict]
fig.legend(fig_h, legend, loc='upper center', bbox_to_anchor=(0.5, 1.2),
        ncol=2, frameon=False, prop=ft, columnspacing=1, labelspacing=0)

# ''' last resize '''
# plt.subplots_adjust(right=1.2)
# fig.subplots_adjust(hspace=1)
plt.tight_layout()
# easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)
# Out:
# [ 0.     1.746  6.776 12.58  18.339 23.553]
# [ 0.     1.746  6.776 12.58  18.339 23.553]
# [ 9.615 12.229 14.636 18.994]
# [ 9.615 12.229 14.636 18.994]
# [ 7.249 11.732 21.069 39.698 78.436]
# [ 7.249 11.732 21.069 39.698 78.436]
# [12.73  13.861 15.875 18.491]
# [12.73  13.861 15.875 18.491]

# %%
''' Save figures'''
fig.savefig(fig_path + fig_name+'.pdf', format="pdf", bbox_inches = 'tight')
# easypyplot.pdf.plot_teardown(pp) # it generates wierd chopped figures
