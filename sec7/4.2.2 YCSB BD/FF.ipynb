# %%
''' Required packages. Use python3 -m pip install xxx for all the packages. '''
from pprint import pprint
import pandas as pd
import numpy as np
import matplotlib.font_manager as fm
from matplotlib import pyplot as plt
import easypyplot

# %%
''' Plot parameters. Change only if you want to resize the graph, etc. '''
fig_bar_width = 0.75
fig_dims = (10, 2)
fig_label_fontsize = 12
xy_label_size = 12
ft = fm.FontProperties('Times New Roman')
ft.set_size(fig_label_fontsize)

fig_name = 'graph_sensitivity'

# %%
workload_list = ['18', '24', '30', '36']
fig_scheme_list = ['Pacman Read Access', 'Pacman Write Access',
                   'Harp Read Access', 'Harp Write Access']
workload_dict = {item: item for item in workload_list}
fig_scheme_dict = {item: item for item in fig_scheme_list}

fig_title = 'YCSB Breakdown'
fig_name = '4.2.2 YCSB breakdown'
fig_path = '../../4.2.2/'
fig_ylim = (0, 1.2)
fig_yticks = list(np.arange(fig_ylim[0], fig_ylim[1]+0.01, 0.3))
fig_bar_colors = [easypyplot.color.COLOR_SET[i] for i in [0, 1]]
design_colors = fig_bar_colors
baseline_colors = easypyplot.color.color_scale(design_colors[0], 2, 0.5, 0.75)[::-1]
igc_colors = easypyplot.color.color_scale(design_colors[1], 2, 0.5, 0.75)[::-1]
design_len = 2
assert len(fig_bar_colors) == design_len

# %%
''' Load CCEH data '''
csv_path = 'CCEH.csv'

# pprint(fig_yticks)
csv_hd = pd.read_csv(csv_path, sep=',')
fig_xlabels = []
baseline_xticks = []
fig_data_CCEH = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in fig_scheme_dict):
                row_value.append(row[col])
        fig_data_CCEH.append(row_value)
        fig_xlabels.append(workload_fullname)
        xtick += 2
        baseline_xticks.append(xtick)
assert len(fig_data_CCEH) == len(fig_xlabels) == len(baseline_xticks)
igc_xticks = [item + fig_bar_width for item in baseline_xticks]

pprint(fig_data_CCEH)

''' Layout hit rate '''
layout_scheme_list = ['Pacman GC', 'Harp GC']
layout_scheme_dict = {item: item for item in layout_scheme_list}
csv_hd = pd.read_csv(csv_path, sep=',')
layout_xlabels = []
layout_xticks = []
layout_data_CCEH = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in layout_scheme_dict):
                row_value.append(row[col])
        layout_data_CCEH.append(row_value)
        layout_xlabels.append(workload_fullname)
        xtick += 1
        layout_xticks.append(xtick)
assert len(layout_data_CCEH) == len(layout_xlabels) == len(layout_xticks)

pprint(layout_data_CCEH)
# Out:
# [[0.26552, 0.0028, 0.037160000000000006, 0.0014199999999999998],
#  [0.457, 0.02155, 0.13104000000000002, 0.016309999999999998],
#  [0.68223, 0.05685, 0.22671, 0.04267],
#  [0.8902899999999999, 0.08379, 0.35119, 0.0802]]
# [[4.015, 0.527],
#  [6.723, 2.0669999999999997],
#  [9.612, 3.489],
#  [12.437000000000001, 5.307]]

# %%
''' Load CCEH-P data '''
csv_path = 'CCEH-P.csv'

# pprint(fig_yticks)
csv_hd = pd.read_csv(csv_path, sep=',')
fig_xlabels = []
baseline_xticks = []
fig_data_CCEH_P = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in fig_scheme_dict):
                row_value.append(row[col])
        fig_data_CCEH_P.append(row_value)
        fig_xlabels.append(workload_fullname)
        xtick += 2
        baseline_xticks.append(xtick)
assert len(fig_data_CCEH_P) == len(fig_xlabels) == len(baseline_xticks)
igc_xticks = [item + fig_bar_width for item in baseline_xticks]

pprint(fig_data_CCEH_P)

''' Layout hit rate '''
layout_scheme_list = ['Pacman GC', 'Harp GC']
layout_scheme_dict = {item: item for item in layout_scheme_list}
csv_hd = pd.read_csv(csv_path, sep=',')
layout_xlabels = []
layout_xticks = []
layout_data_CCEH_P = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in layout_scheme_dict):
                row_value.append(row[col])
        layout_data_CCEH_P.append(row_value)
        layout_xlabels.append(workload_fullname)
        xtick += 1
        layout_xticks.append(xtick)
assert len(layout_data_CCEH_P) == len(layout_xlabels) == len(layout_xticks)

pprint(layout_data_CCEH_P)
# Out:
# [[0.30430999999999997, 0.01278, 0.08182, 0.013619999999999998],
#  [0.48108999999999996, 0.0375, 0.17879, 0.03872],
#  [0.66964, 0.07937000000000001, 0.28646, 0.07932],
#  [0.8798600000000001, 0.13717000000000001, 0.39255, 0.11967]]
# [[4.82, 1.359], [7.681, 3.028], [10.838, 4.987], [14.002, 6.882999999999999]]

# %%
''' Load FF data '''
csv_path = 'FF.csv'

# pprint(fig_yticks)
csv_hd = pd.read_csv(csv_path, sep=',')
fig_xlabels = []
baseline_xticks = []
fig_data_FF = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in fig_scheme_dict):
                row_value.append(row[col])
        fig_data_FF.append(row_value)
        fig_xlabels.append(workload_fullname)
        xtick += 2
        baseline_xticks.append(xtick)
assert len(fig_data_FF) == len(fig_xlabels) == len(baseline_xticks)
igc_xticks = [item + fig_bar_width for item in baseline_xticks]

pprint(fig_data_FF)

''' Layout hit rate '''
layout_scheme_list = ['Pacman GC', 'Harp GC']
layout_scheme_dict = {item: item for item in layout_scheme_list}
csv_hd = pd.read_csv(csv_path, sep=',')
layout_xlabels = []
layout_xticks = []
layout_data_FF = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in layout_scheme_dict):
                row_value.append(row[col])
        layout_data_FF.append(row_value)
        layout_xlabels.append(workload_fullname)
        xtick += 1
        layout_xticks.append(xtick)
assert len(layout_data_FF) == len(layout_xlabels) == len(layout_xticks)

pprint(layout_data_FF)
# Out:
# [[0.30501, 0.01284, 0.07343, 0.01192],
#  [0.47718999999999995, 0.03575, 0.17357, 0.03821],
#  [0.6612600000000001, 0.07359, 0.2519, 0.06437000000000001],
#  [0.8443, 0.10894000000000001, 0.37605, 0.10885]]
# [[4.816, 1.33], [7.593999999999999, 2.937], [10.353, 4.59], [13.75, 6.29]]

# %%
''' Load MT data '''
csv_path = 'MT.csv'

# pprint(fig_yticks)
csv_hd = pd.read_csv(csv_path, sep=',')
fig_xlabels = []
baseline_xticks = []
fig_data_MT = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in fig_scheme_dict):
                row_value.append(row[col])
        fig_data_MT.append(row_value)
        fig_xlabels.append(workload_fullname)
        xtick += 2
        baseline_xticks.append(xtick)
assert len(fig_data_MT) == len(fig_xlabels) == len(baseline_xticks)
igc_xticks = [item + fig_bar_width for item in baseline_xticks]

pprint(fig_data_MT)

''' Layout hit rate '''
layout_scheme_list = ['Pacman GC', 'Harp GC']
layout_scheme_dict = {item: item for item in layout_scheme_list}
csv_hd = pd.read_csv(csv_path, sep=',')
layout_xlabels = []
layout_xticks = []
layout_data_MT = []
xtick = -1
for idx, row in csv_hd.iterrows():
    workload_fullname = str(int(row[0]))
    if any(workload == workload_fullname for workload in workload_list):
        row_value = []
        for col in row.keys():
            if any(scheme in col for scheme in layout_scheme_dict):
                row_value.append(row[col])
        layout_data_MT.append(row_value)
        layout_xlabels.append(workload_fullname)
        xtick += 1
        layout_xticks.append(xtick)
assert len(layout_data_MT) == len(layout_xlabels) == len(layout_xticks)

pprint(layout_data_MT)
# Out:
# [[0.30462, 0.01256, 0.07198, 0.00873],
#  [0.47856000000000004, 0.0373, 0.17110999999999998, 0.03042],
#  [0.66778, 0.07681, 0.28926999999999997, 0.07587],
#  [0.86535, 0.12037, 0.41531, 0.11373]]
# [[4.739, 1.226], [7.577000000000001, 3.023], [10.897, 4.869], [13.977, 6.683]]

# %%
p, fig = easypyplot.pdf.plot_setup(fig_path + fig_name, fig_dims)

''' plot CCEH '''
fig_ax = fig.add_subplot(1 ,4 ,1)
fig_ax2 = fig_ax.twinx()
easypyplot.format.turn_off_box(fig_ax, twinx_axes=fig_ax2)
fig_data_nparr = np.array(fig_data_CCEH)
baseline_acc_data = fig_data_nparr[:, :2]
igc_acc_data = fig_data_nparr[:, 2:4]
fig_h = []
fig_h += easypyplot.barchart.draw(
    fig_ax, baseline_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels,
    xticks=baseline_xticks,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=baseline_colors)
fig_h += easypyplot.barchart.draw(
    fig_ax, igc_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels,
    xticks=igc_xticks,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=igc_colors)
fig_h2 = []
# easypyplot.format.turn_off_box(ax2)
layout_data_nparr = np.array(layout_data_CCEH)
layout_xticks = [baseline_xticks, igc_xticks]
for group_id in range(design_len):
    print(layout_data_nparr[:, 0])
    fig_h2 += fig_ax2.plot(layout_xticks[group_id], layout_data_nparr[:, group_id],
                marker='*',
                linewidth = '1.0',
                color = '#000000',
                # color = baseline_colors[0],
                markersize = '7.0',
                # prop = ft
                )
''' x axis '''
fig_ax.set_xlim([fig_ax.get_xticks()[0] - 1, fig_ax.get_xticks()[-1] + 1])
avg_xticks = [(baseline_xticks[i] + igc_xticks[i])/2 for i in range(len(baseline_xticks))]
fig_ax.set_xticks(avg_xticks)
fig_ax.set_xlim([0, len(workload_list) * design_len + 1])
fig_ax.set_xticklabels(fig_xlabels, fontsize=fig_label_fontsize, fontproperties=ft)
fig_ax.xaxis.set_ticks_position('none') # Comment this and the next line for visible ticks
# fig_ax.tick_params(direction='in') # [in, out, inout]
fig_ax.set_xlabel('Number of Threads\nCCEH-D', fontproperties=ft)
''' y axis '''
fig_ax.yaxis.grid(True)
fig_ax.set_ylim(fig_ylim)
fig_ax.set_yticks(fig_yticks)
fig_ax.set_ylabel('# of Access (billion)', multialignment='center', fontproperties=ft)
layout_ylim = [0., 16]
fig_ax2.set_ylim(layout_ylim)
fig_ax2.set_yticks(list(np.arange(layout_ylim[0], layout_ylim[1]+0.01, 4)))
# fig_ax.set_yticklabels(fontsize=fig_label_fontsize)
# fig_ax2.set_yticklabels(fontsize=fig_label_fontsize)
# fig_ax2.set_ylabel('GC Latency', multialignment='center', fontproperties=ft)
fig_ax.tick_params(labelsize=xy_label_size)
fig_ax2.tick_params(labelsize=xy_label_size)
easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)

''' plot CCEH-P '''
fig_ax = fig.add_subplot(1 ,4 ,2)
fig_ax2 = fig_ax.twinx()
easypyplot.format.turn_off_box(fig_ax, twinx_axes=fig_ax2)
fig_data_nparr = np.array(fig_data_CCEH_P)
baseline_acc_data = fig_data_nparr[:, :2]
igc_acc_data = fig_data_nparr[:, 2:4]
# fig_h = []
fig_h += easypyplot.barchart.draw(
    fig_ax, baseline_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels,
    xticks=baseline_xticks,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=baseline_colors)
fig_h += easypyplot.barchart.draw(
    fig_ax, igc_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels,
    xticks=igc_xticks,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=igc_colors)
# fig_h2 = []
# easypyplot.format.turn_off_box(ax2)
layout_data_nparr = np.array(layout_data_CCEH_P)
layout_xticks = [baseline_xticks, igc_xticks]
for group_id in range(design_len):
    print(layout_data_nparr[:, 0])
    fig_h2 += fig_ax2.plot(layout_xticks[group_id], layout_data_nparr[:, group_id],
                marker='*',
                linewidth = '1.0',
                color = '#000000',
                # color = baseline_colors[0],
                markersize = '7.0',
                # prop = ft
                )
''' x axis '''
fig_ax.set_xlim([fig_ax.get_xticks()[0] - 1, fig_ax.get_xticks()[-1] + 1])
avg_xticks = [(baseline_xticks[i] + igc_xticks[i])/2 for i in range(len(baseline_xticks))]
fig_ax.set_xticks(avg_xticks)
fig_ax.set_xlim([0, len(workload_list) * design_len + 1])
fig_ax.set_xticklabels(fig_xlabels, fontsize=fig_label_fontsize, fontproperties=ft)
fig_ax.xaxis.set_ticks_position('none') # Comment this and the next line for visible ticks
# fig_ax.tick_params(direction='in') # [in, out, inout]
fig_ax.set_xlabel('Number of Threads\nCCEH-P', fontproperties=ft)
''' y axis '''
fig_ax.yaxis.grid(True)
fig_ax.set_ylim(fig_ylim)
fig_ax.set_yticks(fig_yticks)
# fig_ax.set_ylabel('Access Breakdown', multialignment='center', fontproperties=ft)
layout_ylim = [0., 16]
fig_ax2.set_ylim(layout_ylim)
fig_ax2.set_yticks(list(np.arange(layout_ylim[0], layout_ylim[1]+0.01, 4)))
# fig_ax2.set_ylabel('GC Latency', multialignment='center', fontproperties=ft)
fig_ax.tick_params(labelsize=xy_label_size)
fig_ax2.tick_params(labelsize=xy_label_size)
easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)

''' plot FF '''
fig_ax = fig.add_subplot(1 ,4 ,3)
fig_ax2 = fig_ax.twinx()
easypyplot.format.turn_off_box(fig_ax, twinx_axes=fig_ax2)
fig_data_nparr = np.array(fig_data_FF)
baseline_acc_data = fig_data_nparr[:, :2]
igc_acc_data = fig_data_nparr[:, 2:4]
# fig_h = []
fig_h += easypyplot.barchart.draw(
    fig_ax, baseline_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels,
    xticks=baseline_xticks,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=baseline_colors)
fig_h += easypyplot.barchart.draw(
    fig_ax, igc_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels,
    xticks=igc_xticks,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=igc_colors)
# fig_h2 = []
# easypyplot.format.turn_off_box(ax2)
layout_data_nparr = np.array(layout_data_FF)
layout_xticks = [baseline_xticks, igc_xticks]
for group_id in range(design_len):
    print(layout_data_nparr[:, 0])
    fig_h2 += fig_ax2.plot(layout_xticks[group_id], layout_data_nparr[:, group_id],
                marker='*',
                linewidth = '1.0',
                color = '#000000',
                # color = baseline_colors[0],
                markersize = '7.0',
                # prop = ft
                )
''' x axis '''
fig_ax.set_xlim([fig_ax.get_xticks()[0] - 1, fig_ax.get_xticks()[-1] + 1])
avg_xticks = [(baseline_xticks[i] + igc_xticks[i])/2 for i in range(len(baseline_xticks))]
fig_ax.set_xticks(avg_xticks)
fig_ax.set_xlim([0, len(workload_list) * design_len + 1])
fig_ax.set_xticklabels(fig_xlabels, fontsize=fig_label_fontsize, fontproperties=ft)
fig_ax.xaxis.set_ticks_position('none') # Comment this and the next line for visible ticks
# fig_ax.tick_params(direction='in') # [in, out, inout]
fig_ax.set_xlabel('Number of Threads\nFF', fontproperties=ft)
''' y axis '''
fig_ax.yaxis.grid(True)
fig_ax.set_ylim(fig_ylim)
fig_ax.set_yticks(fig_yticks)
# fig_ax.set_ylabel('Access Breakdown', multialignment='center', fontproperties=ft)
layout_ylim = [0., 16]
fig_ax2.set_ylim(layout_ylim)
fig_ax2.set_yticks(list(np.arange(layout_ylim[0], layout_ylim[1]+0.01, 4)))
# fig_ax2.set_ylabel('GC Latency', multialignment='center', fontproperties=ft)
fig_ax.tick_params(labelsize=xy_label_size)
fig_ax2.tick_params(labelsize=xy_label_size)
easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)

''' plot MT '''
fig_ax = fig.add_subplot(1 ,4 ,4)
fig_ax2 = fig_ax.twinx()
easypyplot.format.turn_off_box(fig_ax, twinx_axes=fig_ax2)
fig_data_nparr = np.array(fig_data_MT)
baseline_acc_data = fig_data_nparr[:, :2]
igc_acc_data = fig_data_nparr[:, 2:4]
# fig_h = []
fig_h += easypyplot.barchart.draw(
    fig_ax, baseline_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels,
    xticks=baseline_xticks,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=baseline_colors)
fig_h += easypyplot.barchart.draw(
    fig_ax, igc_acc_data,
    width=fig_bar_width,
    breakdown=True,
    group_names=fig_xlabels,
    xticks=igc_xticks,
    xticklabelfontsize=fig_label_fontsize,
    xticklabelrotation=0,
    # prop=ft,
    colors=igc_colors)
# fig_h2 = []
# easypyplot.format.turn_off_box(fig)
layout_data_nparr = np.array(layout_data_MT)
layout_xticks = [baseline_xticks, igc_xticks]
for group_id in range(design_len):
    print(layout_data_nparr[:, 0])
    fig_h2 += fig_ax2.plot(layout_xticks[group_id], layout_data_nparr[:, group_id],
                marker='*',
                linewidth = '1.0',
                color = '#000000',
                # color = baseline_colors[0],
                markersize = '7.0',
                # prop = ft
                )
''' x axis '''
fig_ax.set_xlim([fig_ax.get_xticks()[0] - 1, fig_ax.get_xticks()[-1] + 1])
avg_xticks = [(baseline_xticks[i] + igc_xticks[i])/2 for i in range(len(baseline_xticks))]
fig_ax.set_xticks(avg_xticks)
fig_ax.set_xlim([0, len(workload_list) * design_len + 1])
fig_ax.set_xticklabels(fig_xlabels, fontsize=fig_label_fontsize, fontproperties=ft)
fig_ax.xaxis.set_ticks_position('none') # Comment this and the next line for visible ticks
# fig_ax.tick_params(direction='in') # [in, out, inout]
fig_ax.set_xlabel('Number of Threads\nMasstree', fontproperties=ft)
''' y axis '''
fig_ax.yaxis.grid(True)
fig_ax.set_ylim(fig_ylim)
fig_ax.set_yticks(fig_yticks)
# fig_ax.set_ylabel('Access Breakdown', multialignment='center', fontproperties=ft)
layout_ylim = [0., 16]
fig_ax2.set_ylim(layout_ylim)
fig_ax2.set_yticks(list(np.arange(layout_ylim[0], layout_ylim[1]+0.01, 4)))
fig_ax2.set_ylabel('# of GC (thousand)', multialignment='center', fontproperties=ft)

''' legend '''
legend_h = fig_h
legend_txt = [fig_scheme_dict[item] for item in fig_scheme_dict]
fig.legend(legend_h, legend_txt, loc='upper center', bbox_to_anchor=(0.5, 1.2),
        ncol=2, frameon=False, prop=ft, columnspacing=1, labelspacing=0)

# ''' last resize '''
# plt.subplots_adjust(right=1.2)
# fig.subplots_adjust(hspace=1)
plt.tight_layout()
fig_ax.tick_params(labelsize=xy_label_size)
fig_ax2.tick_params(labelsize=xy_label_size)
# easypyplot.format.resize_ax_box(fig_ax, hratio=0.8)
# Out:
# [ 4.015  6.723  9.612 12.437]
# [ 4.015  6.723  9.612 12.437]
# [ 4.82   7.681 10.838 14.002]
# [ 4.82   7.681 10.838 14.002]
# [ 4.816  7.594 10.353 13.75 ]
# [ 4.816  7.594 10.353 13.75 ]
# [ 4.739  7.577 10.897 13.977]
# [ 4.739  7.577 10.897 13.977]

# %%
''' Save figures'''
fig.savefig(fig_path + fig_name+'.pdf', format="pdf", bbox_inches = 'tight')
# easypyplot.pdf.plot_teardown(pp) # it generates wierd chopped figures
